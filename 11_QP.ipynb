# %% [markdown]
# # Saveetha Engineering College
# (Autonomous)
# Affiliated to Anna University, Chennai
#
# ## UNIVERSITY LAB EXAMINATION
# **Subject:** 19AI406 - Digital Image Processing Laboratory
# **Date:** 20.11.2025
#
# **Name of the Student:** NAINA MOHAMED Z
# **Register Number:** 212223230131
# **Department:** AI & DS

# %% [markdown]
# ### Question 1
#
# Write a Python program using OpenCV to:
#
# 1. Read an image (road_lanes.png) and convert it to **grayscale**.
# 2. Apply **Global Thresholding** using `cv2.threshold()` with a fixed threshold value.
# 3. Display the **original grayscale image** and the **global thresholded image** using Matplotlib in a **1 × 2 layout**, each with an appropriate **title**.

# %%
# Import
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the image using OpenCV

img = cv2.imread("road_lanes.png", 0)
plt.imshow(img, cmap='gray')

# %%
C = 127 
ret,thresh=cv2.threshold(img,threshold_value,255,cv2.THRESH_BINARY)
plt.title("threshold image")
plt.imshow(thresh)

# %%
# Display the image using Matplotlib
plt.figure(figsize=(40,20))
plt.subplot(141);plt.imshow(img,cmap="gray");plt.title("Original Grayscale Image");plt.axis("Off")
plt.subplot(142);plt.imshow(thresh,cmap="gray");plt.title("Threshold Image");plt.axis("Off")
# Out:
# (np.float64(-0.5), np.float64(764.5), np.float64(345.5), np.float64(-0.5))

# %% [markdown]
# ### Question 2
#
# Write a Python program using OpenCV to:
#
# 1. Read an image (Piano_Sheet_Music.png) and convert it to **grayscale**.
# 2. Apply **Adaptive Thresholding** (Mean or Gaussian) using `cv2.adaptiveThreshold()`.
# 3. Display the **original grayscale image** and the **adaptive thresholded image** using Matplotlib in a **1 × 2 layout**, each with an appropriate **title**.

# %%
img1=cv2.imread("Piano_Sheet_Music.png",0)

# %%
plt.imshow(img1,cmap="gray")

# %%
adap= cv2.adaptiveThreshold(img1,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2)

# %%
plt.imshow(img1)

# %%
plt.figure(figsize=(40,20))
plt.subplot(141);plt.imshow(img1,cmap="gray");plt.title("Original Grayscale Image");plt.axis("Off")
plt.subplot(142);plt.imshow(adap, cmap = 'gray');plt.title("Adaptive Image");plt.axis("Off")
# Out:
# (np.float64(-0.5), np.float64(553.5), np.float64(418.5), np.float64(-0.5))

# %% [markdown]
# ### Question 3
#
# Write a Python program using OpenCV to:
#
# 1. Read an image (road_lanes.png) and convert it to **grayscale**.
# 2. Apply **Otsu’s Thresholding** using `cv2.threshold()` with the `cv2.THRESH_OTSU` flag.
# 3. Display the **original grayscale image** and the **Otsu-thresholded image** using Matplotlib in a **1 × 2 layout**, each with an appropriate **title**.

# %%
img2 = cv2.imread("road_lanes.png", 0)
plt.imshow(img, cmap='gray')

# %%
ret,th_ots=cv2.threshold(img2,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# %%
plt.imshow(th_ots,cmap="gray")

# %%
plt.figure(figsize=(40,20))
plt.subplot(141);plt.imshow(img2,cmap="gray");plt.title("Original Grayscale Image");plt.axis("Off")
plt.subplot(142);plt.imshow(th_ots, cmap = 'gray');plt.title("threshold_otsu Image");plt.axis("Off")
# Out:
# (np.float64(-0.5), np.float64(764.5), np.float64(345.5), np.float64(-0.5))
